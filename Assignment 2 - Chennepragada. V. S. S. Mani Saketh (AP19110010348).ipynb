# %% [markdown]
# ## Chennapragada. V. S. S. Mani Saketh
# ## AP19110010348
# ## CSE - C
# ## ML Assignment 2

# %% [markdown]
# Use python scikit-learn package for the following programs.
#
# 1. Implement Decision Tree Classifier for classification of Iris dataset
#         a. Load the data set
#         b. Split the data set to train and test sets
#         c. Train a Decision Tree using train set
#         d. Test the model using test set.
#         e. Find accuracy and confusion Matrix.

# %%
#Importing Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
#loading the data set
df = pd.read_csv('iris.csv')

y = df['Species']
x = df.drop('Species', axis=1)

#splitting the data set into training set and test set
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
#Training Data set using decision Tree Classifier Model
decisionTree = DecisionTreeClassifier()

decisionTree.fit(x_train,y_train)
#Testing the model with Test Data Set
y_pred = decisionTree.predict(x_test)
#Printing Predicted values and actual data set values
print("Y predicted-\n ",y_pred)
print("\n")
print("Y actual values of test data set-\n ",y_test)
print("\n")
#Printing accuracy value
print("Accuracy- ",metrics.accuracy_score(y_test,y_pred))
#Printing Confusion Matrix
print("\nConfusion Matrix - \n")
print(confusion_matrix(y_test, y_pred))
#Printing Classification Report
print("\nClassification Report - \n")
print(classification_report(y_test, y_pred))
# Out:
# Y predicted-
#   ['versicolor' 'setosa' 'setosa' 'virginica' 'virginica' 'virginica'
#  'virginica' 'virginica' 'setosa' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'versicolor' 'setosa' 'virginica' 'versicolor' 'versicolor'
#  'setosa' 'virginica' 'versicolor' 'virginica' 'virginica' 'virginica'
#  'setosa' 'virginica' 'versicolor' 'versicolor' 'versicolor' 'setosa'
#  'versicolor' 'setosa' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'virginica' 'setosa' 'setosa' 'setosa' 'versicolor' 'setosa'
#  'setosa' 'versicolor']
#
#
# Y actual values of test data set-
#   82     versicolor
# 26         setosa
# 27         setosa
# 102     virginica
# 130     virginica
# 142     virginica
# 109     virginica
# 139     virginica
# 18         setosa
# 81     versicolor
# 143     virginica
# 60     versicolor
# 129     virginica
# 86     versicolor
# 34         setosa
# 131     virginica
# 80     versicolor
# 63     versicolor
# 21         setosa
# 104     virginica
# ...

# %% [markdown]
# Use python scikit-learn package for the following programs.
#
# 2. Implement Random Forest Classifier for classification of Iris dataset
#         a. Load the data set
#         b. Split the data set to train and test sets
#         c. Train a Random Forest model using train set
#         d. Test the model using test set.
#         e. Find accuracy and confusion Matrix.

# %%
#Importing Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
#loading the data set
df = pd.read_csv('iris.csv')

y = df['Species']
x = df.drop('Species', axis=1)
#splitting the data set into training set and test set
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
#Training Data set using Random Forest Classifier Model
randomForestClassifer = RandomForestClassifier()
randomForestClassifer.fit(x_train,y_train)
#Testing the model with Test Data Set
y_pred = decisionTree.predict(x_test)
#Printing Predicted values and actual data set values
print("Y predicted-\n ",y_pred)
print("\n")
print("Y actual values of test data set-\n ",y_test)
print("\n")
#Printing accuracy value
print("Accuracy- ",metrics.accuracy_score(y_test,y_pred))
#Printing Confusion Matrix
print("\nConfusion Matrix - \n")
print(confusion_matrix(y_test, y_pred))
#Printing Classification Report
print("\nClassification Report - \n")
print(classification_report(y_test, y_pred))
# Out:
# Y predicted-
#   ['virginica' 'versicolor' 'versicolor' 'setosa' 'virginica' 'setosa'
#  'versicolor' 'setosa' 'virginica' 'virginica' 'setosa' 'setosa'
#  'virginica' 'setosa' 'setosa' 'setosa' 'virginica' 'setosa' 'virginica'
#  'versicolor' 'virginica' 'setosa' 'setosa' 'setosa' 'virginica'
#  'versicolor' 'versicolor' 'virginica' 'virginica' 'setosa' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'virginica' 'virginica'
#  'versicolor' 'setosa' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'versicolor']
#
#
# Y actual values of test data set-
#   147     virginica
# 106     virginica
# 91     versicolor
# 47         setosa
# 127     virginica
# 43         setosa
# 87     versicolor
# 35         setosa
# 120     virginica
# 137     virginica
# 29         setosa
# 28         setosa
# 110     virginica
# 5          setosa
# 18         setosa
# 36         setosa
# 126     virginica
# 33         setosa
# 111     virginica
# 54     versicolor
# ...
